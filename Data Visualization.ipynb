# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("AB_NYC_2019.csv")

# %%
df
# Out:
#          id                                              name  host_id  \
# 0      2539                Clean & quiet apt home by the park     2787
# 1      2595                             Skylit Midtown Castle     2845
# 2      3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3      3831                   Cozy Entire Floor of Brownstone     4869
# 4      5022  Entire Apt: Spacious Studio/Loft by central park     7192
# ...     ...                                               ...      ...
# 48901  5441                   Central Manhattan/near Broadway     7989
# 48902  5803    Lovely Room 1, Garden, Best Area, Legal rental     9744
# 48903  6021  Wonderful Guest Bedroom in Manhattan for SINGLES    11528
# 48904  6090                     West Village Nest - Superhost    11975
# 48905  6848                  Only 2 stops to Manhattan studio    15991
#
#            host_name neighbourhood_group    neighbourhood  latitude  \
# ...

# %%
df.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
df.isna().sum()
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
df.dropna(inplace =True)
df.drop_duplicates(inplace =True)

# %%
df.isna().sum()
# Out:
# id                                0
# name                              0
# host_id                           0
# host_name                         0
# neighbourhood_group               0
# neighbourhood                     0
# latitude                          0
# longitude                         0
# room_type                         0
# price                             0
# minimum_nights                    0
# number_of_reviews                 0
# last_review                       0
# reviews_per_month                 0
# calculated_host_listings_count    0
# availability_365                  0
# dtype: int64

# %%
df["id"]= df["id"].astype(str)
df["host_id"]= df["host_id"].astype(str)
df["latitude"]= df["latitude"].astype(str)
df["longitude"]= df["longitude"].astype(str)

# %%
df.describe()
# Out:
#               price  minimum_nights  number_of_reviews  reviews_per_month  \
# count  38821.000000    38821.000000       38821.000000       38821.000000
# mean     142.332526        5.869220          29.290255           1.373229
# std      196.994756       17.389026          48.182900           1.680328
# min        0.000000        1.000000           1.000000           0.010000
# 25%       69.000000        1.000000           3.000000           0.190000
# 50%      101.000000        2.000000           9.000000           0.720000
# 75%      170.000000        4.000000          33.000000           2.020000
# max    10000.000000     1250.000000         629.000000          58.500000
#
#        calculated_host_listings_count  availability_365
# count                    38821.000000      38821.000000
# mean                         5.166611        114.886299
# std                         26.302954        129.529950
# min                          1.000000          0.000000
# ...

# %%
df.nunique()
# Out:
# id                                38821
# name                              38244
# host_id                           30232
# host_name                          9885
# neighbourhood_group                   5
# neighbourhood                       218
# latitude                          17436
# longitude                         13639
# room_type                             3
# price                               581
# minimum_nights                       89
# number_of_reviews                   393
# last_review                        1764
# reviews_per_month                   937
# calculated_host_listings_count       47
# availability_365                    366
# dtype: int64

# %% [markdown]
# ## Categorical

# %% [markdown]
# ## This value counts help me to count that in a particular city of New Work, how many hotels

# %%
df["neighbourhood_group"].value_counts()
# Out:
# neighbourhood_group
# Manhattan        16621
# Brooklyn         16439
# Queens            4572
# Bronx              875
# Staten Island      314
# Name: count, dtype: int64

# %% [markdown]
# ## This value counts help me to count percentage that in a particular city of New Work, how many hotels

# %%
df["neighbourhood_group"].value_counts(normalize = True)
# Out:
# neighbourhood_group
# Manhattan        0.428145
# Brooklyn         0.423456
# Queens           0.117771
# Bronx            0.022539
# Staten Island    0.008088
# Name: proportion, dtype: float64

# %% [markdown]
# ## This value counts help me to count that in a how many type of room

# %%
df["room_type"].value_counts()
# Out:
# room_type
# Entire home/apt    20321
# Private room       17654
# Shared room          846
# Name: count, dtype: int64

# %% [markdown]
# ## This value counts help me to count percentage that in a how many type of room

# %%
df["room_type"].value_counts(normalize = True)
# Out:
# room_type
# Entire home/apt    0.523454
# Private room       0.454754
# Shared room        0.021792
# Name: proportion, dtype: float64

# %%
df_n = df["neighbourhood"].value_counts().reset_index().rename(columns={"index":"neighbourhood", "neighbourhood":"number_of_hotels"})

# %% [markdown]
# # Numeric

# %% [markdown]
# ## By bins in dataframe the whole domain, that means the maximum price the minimum price gets divided into five intervals

# %%
df["price"].value_counts(bins = 5)
# Out:
# (-10.001, 2000.0]    38786
# (2000.0, 4000.0]        20
# (4000.0, 6000.0]         8
# (8000.0, 10000.0]        5
# (6000.0, 8000.0]         2
# Name: count, dtype: int64

# %%
bins = (0, 50, 100, 200, 500, 2000, 10000)

# %%
df["price"].value_counts(bins=bins)
# Out:
# (50.0, 100.0]        14212
# (100.0, 200.0]       13544
# (200.0, 500.0]        5267
# (-0.001, 50.0]        5176
# (500.0, 2000.0]        587
# (2000.0, 10000.0]       35
# Name: count, dtype: int64

# %%
df["price"].mean()
# Out:
# 142.33252621004095

# %%
df["price"].std()
# Out:
# 196.99475591833985

# %%
df["price"].skew()
# Out:
# 23.673594295123014

# %%
df["price"].kurt()
# Out:
# 953.4807356344944

# %%
sns.countplot(data = df, x = "neighbourhood_group")
# Out:
# <Axes: xlabel='neighbourhood_group', ylabel='count'>

# %%
sns.countplot(data = df, x = "room_type")
# Out:
# <Axes: xlabel='room_type', ylabel='count'>

# %%
sns.countplot(data = df, x = "neighbourhood_group", hue="room_type")
# Out:
# <Axes: xlabel='neighbourhood_group', ylabel='count'>

# %%
df["room_type"].value_counts().plot(kind= "pie")
# Out:
# <Axes: ylabel='count'>

# %%
df["room_type"].value_counts().plot(kind= "pie", autopct= "%.2f")
# Out:
# <Axes: ylabel='count'>

# %%
df["neighbourhood_group"].value_counts().plot(kind= "pie", autopct = "%.2f")
# Out:
# <Axes: ylabel='count'>

# %%
df["room_type"].value_counts().plot(kind= "bar")
# Out:
# <Axes: xlabel='room_type'>

# %%
df2 = sns.load_dataset("titanic")
df2.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sns.countplot(data = df2, x = "survived", hue = "sex")
# Out:
# <Axes: xlabel='survived', ylabel='count'>

# %%
sns.countplot(data = df2, x = "class", hue = "survived")
# Out:
# <Axes: xlabel='class', ylabel='count'>

# %%
df2["class"].value_counts().plot(kind= "pie", autopct = "%.2f")
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# # Histogram

# %%
sns.histplot(data = df, x= "price")
# Out:
# <Axes: xlabel='price', ylabel='Count'>

# %%
sns.histplot(data = df[df["price"]<1000], x= "price")
# Out:
# <Axes: xlabel='price', ylabel='Count'>

# %%
sns.histplot(data = df[df["price"]<500], x= "price")
# Out:
# <Axes: xlabel='price', ylabel='Count'>

# %%
sns.histplot(data = df, x= "availability_365")
# Out:
# <Axes: xlabel='availability_365', ylabel='Count'>

# %%
sns.violinplot(data = df, x= "availability_365")
# Out:
# <Axes: xlabel='availability_365'>

# %%
sns.distplot(df["price"])
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_9720\50337492.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["price"])
# <Axes: xlabel='price', ylabel='Density'>

# %%
sns.distplot(df["availability_365"])
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_9720\1603039620.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["availability_365"])
# <Axes: xlabel='availability_365', ylabel='Density'>

# %% [markdown]
# # Boxplot

# %%
sns.boxplot(df["price"])
# Out:
# <Axes: ylabel='price'>

# %%
sns.boxplot(df["availability_365"])
# Out:
# <Axes: ylabel='availability_365'>

# %%
df2.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sns.histplot(data = df2, x = "fare")
# Out:
# <Axes: xlabel='fare', ylabel='Count'>

# %%
sns.distplot(df2["fare"])
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_9720\3524834500.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df2["fare"])
# <Axes: xlabel='fare', ylabel='Density'>

# %%
sns.boxplot(df2["fare"])
# Out:
# <Axes: ylabel='fare'>

# %%
sns.boxplot(df2["age"])
# Out:
# <Axes: ylabel='age'>

# %% [markdown]
# ## Instead of boxplot, we can also use violin plot. Violin plot helps me to give all the boxplot values and also the probability distribution

# %%
sns.violinplot(df2["age"])
# Out:
# <Axes: ylabel='age'>

# %%
sns.barplot(x = "class", y = "age", data = df2)
# Out:
# <Axes: xlabel='class', ylabel='age'>

# %%
sns.barplot(x = "class", y = "fare", data = df2, estimator = "sum")
# Out:
# <Axes: xlabel='class', ylabel='fare'>

# %%
sns.barplot(x = "class", y = "fare", data = df2, estimator = "sum", hue = "sex")
# Out:
# <Axes: xlabel='class', ylabel='fare'>

# %%
sns.barplot(x = "class", y = "age", data = df2, estimator = "sum", hue = "sex")
# Out:
# <Axes: xlabel='class', ylabel='age'>

# %%
sns.boxplot(x = "class", y = "age", data = df2)
# Out:
# <Axes: xlabel='class', ylabel='age'>

# %%
sns.violinplot(x = "class", y = "age", data = df2)
# Out:
# <Axes: xlabel='class', ylabel='age'>

# %%
sns.boxplot(x = "class", y = "age", data = df2, hue = "survived")
# Out:
# <Axes: xlabel='class', ylabel='age'>

# %%
sns.distplot(df2[df2["class"] == "Second"]["age"])
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_9720\2606464261.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df2[df2["class"] == "Second"]["age"])
# <Axes: xlabel='age', ylabel='Density'>

# %%
x = pd.crosstab(df2["survived"], df2["class"])

# %%
x
# Out:
# class     First  Second  Third
# survived
# 0            80      97    372
# 1           136      87    119

# %% [markdown]
# ## Heat map

# %%
sns.heatmap(x)
# Out:
# <Axes: xlabel='class', ylabel='survived'>

# %%
sns.heatmap(x, annot = True)
# Out:
# <Axes: xlabel='class', ylabel='survived'>

# %%
sns.heatmap(x, annot = True, fmt = ".1f")
# Out:
# <Axes: xlabel='class', ylabel='survived'>

# %%
sns.heatmap(x, annot = True, fmt = ".1f", cmap = "coolwarm")
# Out:
# <Axes: xlabel='class', ylabel='survived'>

# %%
sns.barplot(x = "class", y = "age", data = df2, estimator = "sum", hue = "sex")
# Out:
# <Axes: xlabel='class', ylabel='age'>

# %%
sns.stripplot(x = "class", y = "age", data = df2, hue = "sex")
# Out:
# <Axes: xlabel='class', ylabel='age'>

# %%
df3 = sns.load_dataset("iris")
df3.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df3.head().plot(kind = "bar")
# Out:
# <Axes: >

# %%
df3.head().plot(kind = "bar", stacked = True)
# Out:
# <Axes: >

# %% [markdown]
# ## Pair plot help us to get all the graphs at once.

# %%
sns.pairplot(df3)

# %% [markdown]
# ##  when we are working on numerical data and if i have to find out a relationship Scatter Plot help us a lot.

# %%
sns.scatterplot(x = "age", y = "fare", data = df2)
# Out:
# <Axes: xlabel='age', ylabel='fare'>

# %%
sns.scatterplot(x = "age", y = "fare", data = df2, hue = "survived")
# Out:
# <Axes: xlabel='age', ylabel='fare'>

# %%
df4 =  sns.load_dataset("tips")

# %%
df4.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.scatterplot(x = "total_bill", y = "tip", data = df4)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(x = "total_bill", y = "tip", data = df4, hue = "sex")
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(x = "total_bill", y = "tip", data = df4, hue = "sex", style = "smoker")
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# ## Jointplot - Its gives me both my distribution and also a scatter plot

# %%
sns.jointplot(x = "total_bill", y = "tip", data = df4)

# %%
sns.jointplot(x = "total_bill", y = "tip", data = df4, hue = "sex")

# %%
sns.jointplot(x = "total_bill", y = "tip", data = df4, kind = "reg")

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
df5 = sns.load_dataset("dowjones")

# %%
df5.head()
# Out:
#         Date  Price
# 0 1914-12-01  55.00
# 1 1915-01-01  56.55
# 2 1915-02-01  56.00
# 3 1915-03-01  58.30
# 4 1915-04-01  66.45

# %%
df5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 649 entries, 0 to 648
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    649 non-null    datetime64[ns]
#  1   Price   649 non-null    float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 10.3 KB

# %%
df5["Month"] = df5["Date"].dt.month
df5["Year"] = df5["Date"].dt.year

# %%
df5.head()
# Out:
#         Date  Price  Month  Year
# 0 1914-12-01  55.00     12  1914
# 1 1915-01-01  56.55      1  1915
# 2 1915-02-01  56.00      2  1915
# 3 1915-03-01  58.30      3  1915
# 4 1915-04-01  66.45      4  1915
